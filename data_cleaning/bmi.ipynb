# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/BMI_data.csv')

# %%
df
# Out:
#       IndicatorCode                                     Indicator ValueType  \
# 0      NCD_BMI_MEAN  Mean BMI (kg/m²) (age-standardized estimate)   numeric
# 1      NCD_BMI_MEAN  Mean BMI (kg/m²) (age-standardized estimate)   numeric
# 2      NCD_BMI_MEAN  Mean BMI (kg/m²) (age-standardized estimate)   numeric
# 3      NCD_BMI_MEAN  Mean BMI (kg/m²) (age-standardized estimate)   numeric
# 4      NCD_BMI_MEAN  Mean BMI (kg/m²) (age-standardized estimate)   numeric
# ...             ...                                           ...       ...
# 24565  NCD_BMI_MEAN  Mean BMI (kg/m²) (age-standardized estimate)   numeric
# 24566  NCD_BMI_MEAN  Mean BMI (kg/m²) (age-standardized estimate)   numeric
# 24567  NCD_BMI_MEAN  Mean BMI (kg/m²) (age-standardized estimate)   numeric
# 24568  NCD_BMI_MEAN  Mean BMI (kg/m²) (age-standardized estimate)   numeric
# 24569  NCD_BMI_MEAN  Mean BMI (kg/m²) (age-standardized estimate)   numeric
#
#       ParentLocationCode         ParentLocation Location type  \
# 0                    AFR                 Africa       Country
# 1                    AFR                 Africa       Country
# 2                    AFR                 Africa       Country
# 3                    AFR                 Africa       Country
# 4                    AFR                 Africa       Country
# ...                  ...                    ...           ...
# 24565                AFR                 Africa       Country
# 24566                AFR                 Africa       Country
# 24567                EMR  Eastern Mediterranean       Country
# 24568                EMR  Eastern Mediterranean       Country
# 24569                EMR  Eastern Mediterranean       Country
#
#       SpatialDimValueCode     Location Period type  Period  ...  FactValueUoM  \
# 0                     ETH     Ethiopia        Year    2016  ...           NaN
# 1                     ERI      Eritrea        Year    2016  ...           NaN
# 2                     ETH     Ethiopia        Year    2016  ...           NaN
# 3                     ERI      Eritrea        Year    2016  ...           NaN
# 4                     MDG   Madagascar        Year    2016  ...           NaN
# ...                   ...          ...         ...     ...  ...           ...
# 24565                 SSD  South Sudan        Year    1975  ...           NaN
# 24566                 SSD  South Sudan        Year    1975  ...           NaN
# 24567                 SDN        Sudan        Year    1975  ...           NaN
# 24568                 SDN        Sudan        Year    1975  ...           NaN
# 24569                 SDN        Sudan        Year    1975  ...           NaN
#
#       FactValueNumericLowPrefix FactValueNumericLow  \
# 0                           NaN                19.0
# 1                           NaN                19.2
# 2                           NaN                19.8
# 3                           NaN                19.9
# 4                           NaN                19.9
# ...                         ...                 ...
# 24565                       NaN                 NaN
# 24566                       NaN                 NaN
# 24567                       NaN                 NaN
# 24568                       NaN                 NaN
# 24569                       NaN                 NaN
#
#       FactValueNumericHighPrefix FactValueNumericHigh               Value  \
# 0                            NaN                 21.0      20.1 [19 – 21]
# 1                            NaN                 21.3  20.2 [19.2 – 21.3]
# 2                            NaN                 21.3  20.6 [19.8 – 21.3]
# 3                            NaN                 21.5  20.7 [19.9 – 21.5]
# 4                            NaN                 22.3  21.1 [19.9 – 22.3]
# ...                          ...                  ...                 ...
# 24565                        NaN                  NaN             No data
# 24566                        NaN                  NaN             No data
# 24567                        NaN                  NaN             No data
# 24568                        NaN                  NaN             No data
# 24569                        NaN                  NaN             No data
#
#       FactValueTranslationID  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 24565                  827.0
# 24566                  827.0
# 24567                  827.0
# 24568                  827.0
# 24569                  827.0
#
#                                             FactComments  Language  \
# 0                                                    NaN        EN
# 1                                                    NaN        EN
# 2                                                    NaN        EN
# 3                                                    NaN        EN
# 4                                                    NaN        EN
# ...                                                  ...       ...
# 24565  No data available.� Estimate could not be calc...        EN
# 24566  No data available.� Estimate could not be calc...        EN
# 24567  No data available.� Estimate could not be calc...        EN
# 24568  No data available.� Estimate could not be calc...        EN
# 24569  No data available.� Estimate could not be calc...        EN
#
#                    DateModified
# 0      2017-09-26T23:00:00.000Z
# 1      2017-09-26T23:00:00.000Z
# 2      2017-09-26T23:00:00.000Z
# 3      2017-09-26T23:00:00.000Z
# 4      2017-09-26T23:00:00.000Z
# ...                         ...
# 24565  2017-09-26T23:00:00.000Z
# 24566  2017-09-26T23:00:00.000Z
# 24567  2017-09-26T23:00:00.000Z
# 24568  2017-09-26T23:00:00.000Z
# 24569  2017-09-26T23:00:00.000Z
#
# [24570 rows x 34 columns]

# %%
df[['Period', 'Location', 'Dim1', 'SpatialDimValueCode', 'Value']]
# Out:
#        Period     Location        Dim1 SpatialDimValueCode               Value
# 0        2016     Ethiopia        Male                 ETH      20.1 [19 – 21]
# 1        2016      Eritrea        Male                 ERI  20.2 [19.2 – 21.3]
# 2        2016     Ethiopia  Both sexes                 ETH  20.6 [19.8 – 21.3]
# 3        2016      Eritrea  Both sexes                 ERI  20.7 [19.9 – 21.5]
# 4        2016   Madagascar      Female                 MDG  21.1 [19.9 – 22.3]
# ...       ...          ...         ...                 ...                 ...
# 24565    1975  South Sudan      Female                 SSD             No data
# 24566    1975  South Sudan        Male                 SSD             No data
# 24567    1975        Sudan  Both sexes                 SDN             No data
# 24568    1975        Sudan      Female                 SDN             No data
# 24569    1975        Sudan        Male                 SDN             No data
#
# [24570 rows x 5 columns]

# %%
df = df[['Period', 'Location', 'Dim1', 'SpatialDimValueCode', 'Value']]

# %%
df.columns = ['Year', 'Country', 'Gender', 'Country_Code', 'BMI']

# %%
df.BMI.value_counts()
# Out:
# No data               504
# 25.1 [24.5 – 25.7]     30
# 25 [24.6 – 25.4]       29
# 26 [25.5 – 26.5]       27
# 25.2 [24.6 – 25.8]     27
#                      ...
# 33.3 [32.8 – 33.8]      1
# 19.2 [18.6 – 19.7]      1
# 19.4 [18.3 – 20.7]      1
# 19.5 [18.8 – 20.3]      1
# 33.7 [32.5 – 34.8]      1
# Name: BMI, Length: 7614, dtype: int64

# %%
df = df[df.Gender == 'Both sexes']
df = df.drop('Gender', axis=1)

# %%
def remove_range(cell):
    return cell.split(' ')[0]

# %%
df.BMI = df.BMI.apply(remove_range)

# %%
df.BMI.value_counts()
# Out:
# No      168
# 25      157
# 25.1    155
# 24.9    151
# 25.2    148
#        ...
# 33.1      2
# 17.7      2
# 33.3      2
# 17.6      1
# 17.5      1
# Name: BMI, Length: 164, dtype: int64

# %%
df = df[df.BMI != 'No']

# %%
df.BMI.value_counts()
# Out:
# 25      157
# 25.1    155
# 24.9    151
# 25.2    148
# 25.6    147
#        ...
# 33.1      2
# 17.7      2
# 33.3      2
# 17.6      1
# 17.5      1
# Name: BMI, Length: 163, dtype: int64

# %%
df.BMI = pd.to_numeric(df.BMI)

# %%
df.BMI.value_counts()
# Out:
# 25.0    157
# 25.1    155
# 24.9    151
# 25.2    148
# 25.6    147
#        ...
# 33.1      2
# 17.7      2
# 33.3      2
# 17.6      1
# 17.5      1
# Name: BMI, Length: 163, dtype: int64

# %%
countries = df.Country.unique()
years = df.Year.unique()
years.sort()

dict = {country: [] for country in countries}
for country in countries:
    for year in years:
        value = df[df.Country == country][df.Year == year].BMI
        if value.empty == True:
            dict[country].append(float('NaN'))
        else:
            dict[country].append(float(df[df.Country == country][df.Year == year].BMI))
# Out:
# C:\Users\Charlie\AppData\Local\Temp\ipykernel_62600\1819357059.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   value = df[df.Country == country][df.Year == year].BMI
# C:\Users\Charlie\AppData\Local\Temp\ipykernel_62600\1819357059.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dict[country].append(float(df[df.Country == country][df.Year == year].BMI))

# %%
df = pd.DataFrame(dict)

df['Year'] = [i for i in range(years[0], years[-1]+1)]

df = df.set_index('Year')

df.to_csv('../data/processed/BMI_data.csv')
